# %% [markdown]
# #### Objective

# %% [markdown]
# The objective of the project is to learn reading, manipulating and analysing geographic data and geospatial operations and analysis using python.New York city's child care center dataset and population statistics dataset is used  for geospatial analysis.Identify geographical distribution of children aged 0-5 from population statistics and ditribution of child care centers

# %% [markdown]
# #### Dataset

# %% [markdown]
# Child care center -https://hifld-geoplatform.opendata.arcgis.com/datasets/child-care-centers/
# Population Statistics -https://data.cccnewyork.org/data/download

# %% [markdown]
# #### Library

# %%
import pandas as pd 
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Anupama\\Geomap'

# %% [markdown]
# ### Pre-project work

# %% [markdown]
# Some pre-project work was done to understand basics of geodataframe and geoprocessing.Below are few code snippets from the pre-project work based on sweden pre-school dataset and population statistics.

# %%
population = gpd.read_file("dataset/dataset/pop_statistics.shp")

# %%
population.tail()
population.iloc[[1,25,40],[1,2,3,4,31]]
# Out:
#     Age0_5  Age6_9  Age10_15  Age16_19  \
# 1       37      35        40        24
# 25     151     138       271       135
# 40     185      65        93        48
#
#                                              geometry
# 1   POLYGON ((688731.626 6547758.133, 686809.834 6...
# 25  POLYGON ((670931.034 6572832.649, 670930.539 6...
# 40  POLYGON ((661735.606 6571081.185, 661726.692 6...

# %%
type(population)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# shape area of each object
population.area
# Out:
# 0       5.780289e+07
# 1       1.302095e+08
# 2       1.064226e+08
# 3       1.282950e+08
# 4       4.458383e+08
#             ...
# 5980    7.285478e+08
# 5981    1.836107e+06
# 5982    6.228229e+06
# 5983    1.811785e+09
# 5984    1.433088e+09
# Length: 5985, dtype: float64

# %%
#tuple of max and min coordinates on each axis for each shape
population.bounds
# Out:
#                minx          miny           maxx          maxy
# 0     679217.925921  6.612445e+06  690986.592841  6.621470e+06
# 1     674928.223384  6.535572e+06  688731.626302  6.552060e+06
# 2     687794.774871  6.634099e+06  699545.556590  6.652222e+06
# 3     715471.044123  6.631800e+06  744992.279803  6.643561e+06
# 4     717598.900660  6.615910e+06  755220.730344  6.636198e+06
# ...             ...           ...            ...           ...
# 5980  350809.720175  6.513861e+06  378692.127668  6.557539e+06
# 5981  367900.205770  6.547562e+06  369515.096630  6.549577e+06
# 5982  366577.011352  6.544812e+06  370054.012047  6.548317e+06
# 5983  399694.839159  6.671373e+06  446467.525436  6.748499e+06
# 5984  374232.527456  6.736915e+06  424748.259834  6.788469e+06
#
# [5985 rows x 4 columns]

# %%
#Geometric object has polygon and multi-polygons
population.geom_type
# Out:
# 0            Polygon
# 1            Polygon
# 2            Polygon
# 3            Polygon
# 4            Polygon
#             ...
# 5980         Polygon
# 5981         Polygon
# 5982         Polygon
# 5983    MultiPolygon
# 5984    MultiPolygon
# Length: 5985, dtype: object

# %%
# tests if coordinates make a shape that is reasonable geometric shape
population.is_valid
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 5980     True
# 5981     True
# 5982     True
# 5983     True
# 5984    False
# Length: 5985, dtype: bool

# %%
#population.total_bounds

# %%
population.shape
# Out:
# (5985, 32)

# %%
population.describe()
# Out:
#             Age0_5       Age6_9     Age10_15     Age16_19     Age20_24  \
# count  5985.000000  5985.000000  5985.000000  5985.000000  5985.000000
# mean    121.401671    82.988471   118.574269    74.310777    99.710610
# std      54.816171    39.147961    54.992497    30.605886    71.265027
# min       0.000000     0.000000     0.000000     9.000000     3.000000
# 25%      84.000000    54.000000    78.000000    52.000000    60.000000
# 50%     112.000000    78.000000   110.000000    70.000000    85.000000
# 75%     148.000000   105.000000   152.000000    94.000000   119.000000
# max     541.000000   306.000000   400.000000   240.000000  1262.000000
#
#           Age25_29     Age30_34     Age35_39     Age40_44     Age45_49  ...  \
# count  5985.000000  5985.000000  5985.000000  5985.000000  5985.000000  ...
# mean    123.616708   115.049457   106.705096   106.016374   109.798663  ...
# std      80.912025    59.945579    44.796477    40.588165    38.774269  ...
# min       8.000000    10.000000    13.000000     6.000000     0.000000  ...
# 25%      67.000000    73.000000    75.000000    77.000000    82.000000  ...
# 50%     102.000000   102.000000   100.000000   101.000000   105.000000  ...
# 75%     160.000000   142.000000   130.000000   130.000000   133.000000  ...
# max    1001.000000   759.000000   431.000000   334.000000   318.000000  ...
#
#           Median_Inc     U_median     O_median    Tot20_pop     HH_Child  \
# count    5985.000000  5985.000000  5985.000000  5985.000000  5985.000000
# mean   285435.133333   647.952047   649.822222  1297.774269   174.049958
# std     61541.401238   236.176029   219.424887   322.182859    75.320552
# min      3012.000000    80.000000    16.000000   487.000000     0.000000
# 25%    248679.000000   472.000000   487.000000  1072.000000   119.000000
# 50%    284589.000000   617.000000   639.000000  1299.000000   160.000000
# 75%    320832.000000   791.000000   795.000000  1519.000000   218.000000
# max    562797.000000  2003.000000  1798.000000  2816.000000   550.000000
#
#         HH_NoChild   Single_Chi   Single_NoC       Others     Totalt_3
# count  5985.000000  5985.000000  5985.000000  5985.000000  5985.000000
# mean    187.463158    55.301921   307.431746    53.929490   778.176274
# std      66.046965    26.740170   178.087220    35.170047   233.702336
# min      22.000000     0.000000    19.000000     0.000000   242.000000
# 25%     142.000000    35.000000   167.000000    30.000000   606.000000
# 50%     181.000000    51.000000   271.000000    45.000000   764.000000
# 75%     227.000000    70.000000   419.000000    68.000000   926.000000
# max     673.000000   183.000000  1523.000000   412.000000  2187.000000
#
# [8 rows x 30 columns]

# %%
population.centroid
# Out:
# 0       POINT (684865.309 6616880.074)
# 1       POINT (680943.719 6544424.088)
# 2       POINT (693144.724 6644511.773)
# 3       POINT (727090.120 6636482.416)
# 4       POINT (737307.356 6626393.044)
#                      ...
# 5980    POINT (363855.739 6533473.909)
# 5981    POINT (368756.117 6548583.917)
# 5982    POINT (368579.110 6546514.558)
# 5983    POINT (427752.822 6719761.880)
# 5984    POINT (398546.416 6760947.946)
# Length: 5985, dtype: geometry

# %%
population.crs
# Out:
# <Projected CRS: EPSG:3006>
# Name: SWEREF99 TM
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[east]: Easting (metre)
# Area of Use:
# - name: Sweden
# - bounds: (10.03, 54.96, 24.17, 69.07)
# Coordinate Operation:
# - name: SWEREF99 TM
# - method: Transverse Mercator
# Datum: SWEREF99
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
#population.intersects(preschools)

# %%
#population.contains(preschools)

# %%
population.geometry.name
# Out:
# 'geometry'

# %%
#population.plot()

fig, ax = plt.subplots(figsize=(14, 12),dpi=300)
population.plot(ax=ax,color='yellow',cmap='Accent')
plt.show()

# %%
preschools= gpd.read_file("dataset/dataset/preschools.shp")

# %%
preschools.head()
# Out:
#                                             Name  \
# 0  LIDINGÖ MONTESSORIFÖRSKOLA EKONOMISK FÖRENING
# 1                                 EKERÖ PASTORAT
# 2                   BANKERYDS MISSIONSFÖRSAMLING
# 3            PINGSTLILJANS FÖRSKOLA I TENHULT AB
# 4                           SOLSTRÅLENS FÖRSKOLA
#
#                                  FIRMABEN           Address      City  \
# 0                                    None     HOLMIAVÄGEN 8   LIDINGÖ
# 1  PASTORSEXPEDITION OCH KYRKANS FÖRSKOLA  BJÖRKUDDSVÄGEN 2     EKERÖ
# 2                                    None   EKEFORSVÄGEN 22  BANKERYD
# 3                                    None  VÄSTRA VÄGEN 2 B   TENHULT
# 4                                    None         ÅNARYD 26    GRÄNNA
#
#     POSTORT  POSTNUMMER       POSTADRESS  KOM    KOMTEXT  \
# 0   LIDINGÖ       18131    HOLMIAVÄGEN 8  186    Lidingö
# 1     EKERÖ       17822          BOX 116  125      Ekerö
# 2  BANKERYD       56433  EKEFORSVÄGEN 22  680  Jönköping
# 3   TENHULT       56029   VÄSTRA VÄGEN 2  680  Jönköping
# 4    GRÄNNA       56393        ÅNARYD 26  680  Jönköping
#
#                          geometry
# 0  POINT (678249.000 6585136.000)
# 1  POINT (659668.000 6575276.000)
# 2  POINT (447950.000 6412884.000)
# 3  POINT (459569.000 6396416.000)
# 4  POINT (464770.000 6422324.000)

# %%
preschools.describe()
# Out:
#          POSTNUMMER          KOM
# count   9599.000000  9599.000000
# mean   46316.268465  1127.599229
# std    25765.893893   750.421914
# min    10028.000000   114.000000
# 25%    20580.000000   380.000000
# 50%    43332.000000  1280.000000
# 75%    68680.000000  1494.000000
# max    98492.000000  2584.000000

# %%
preschools.shape
# Out:
# (9599, 10)

# %%
fig, ax = plt.subplots(figsize=(14, 12),dpi=300)
preschools.plot(ax=ax,color='grey')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(14, 12),dpi=300)
plt.title('Choropleth Map - Children Ages between 0 - 5 in NYC', fontsize= 15,  y=0.5)
population.plot(ax=ax,cmap='Accent')
preschools.plot(ax=ax,color='grey')
# Out:
# <AxesSubplot:title={'center':'Choropleth Map - Children Ages between 0 - 5 in NYC'}>

# %% [markdown]
# ### Geoprocessing

# %% [markdown]
# #### Intersection of Polygons

# %%
intersection=gpd.overlay(population,preschools,how='intersection',keep_geom_type=False)
intersection.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Union of Polygons

# %%
union=gpd.overlay(population,preschools,how='union',keep_geom_type=False)
union.plot()
# Out:
# <AxesSubplot:>

# %%
union
# Out:
#             Deso  Age0_5  Age6_9  Age10_15  Age16_19  Age20_24  Age25_29  \
# 0      0136A0010      37      35        40        24        32        32
# 1      0188A0150      71      46        59        59        55        55
# 2      0188A0130      62      39        63        59        38        63
# 3      0188A0060      91      81       105        83        67        71
# 4      0188A0060      91      81       105        83        67        71
# ...          ...     ...     ...       ...       ...       ...       ...
# 15579  1492A0010     115      78       133       100        83       112
# 15580  1492C1030     158     125       213       135       152       142
# 15581  1492C1010      87      76       132        86       124       108
# 15582  2023A0010      87      46        85        53        57        88
# 15583  2023A0020      76      58        78        55        83        73
#
#        Age30_34  Age35_39  Age40_44  ...  \
# 0            25        30        45  ...
# 1            48        57        52  ...
# 2            50        53        48  ...
# 3            86        85        88  ...
# 4            86        85        88  ...
# ...         ...       ...       ...  ...
# 15579        95        85       122  ...
# 15580       140       115       139  ...
# 15581        73        89       104  ...
# 15582        70        77        80  ...
# 15583       100        63        74  ...
#
#                                              Name  \
# 0                                  HANINGE KOMMUN
# 1                                NORRTÄLJE KOMMUN
# 2                                NORRTÄLJE KOMMUN
# 3      VIKTORIAGÅRDEN FÖRSKOLA EKONOMISK FÖRENING
# 4                      VIKTORIAGÅRDEN FÖRSKOLA AB
# ...                                           ...
# 15579                                         NaN
# 15580                                         NaN
# 15581                                         NaN
# 15582                                         NaN
# 15583                                         NaN
#
#                                   FIRMABEN          Address    City  POSTORT  \
# 0                 MUSKÖ SKOLA OCH FÖRSKOLA  ARBOTTNAVÄGEN 1   MUSKÖ  HANINGE
# 1                          EDSBRO FÖRSKOLA  BROKULLAVÄGEN 2  EDSBRO   EDSBRO
# 2      VÄTÖ SKOLA, FRITIDSHEM OCH FÖRSKOLA    HÅKNÄSVÄGEN 6    VÄTÖ     VÄTÖ
# 3                                     None   GRÄDDÖ BYVÄG 6  GRÄDDÖ   GRÄDDÖ
# 4                                     None   GRÄDDÖ BYVÄG 6  GRÄDDÖ   GRÄDDÖ
# ...                                    ...              ...     ...      ...
# 15579                                  NaN              NaN     NaN      NaN
# 15580                                  NaN              NaN     NaN      NaN
# 15581                                  NaN              NaN     NaN      NaN
# 15582                                  NaN              NaN     NaN      NaN
# 15583                                  NaN              NaN     NaN      NaN
#
#        POSTNUMMER      POSTADRESS    KOM    KOMTEXT  \
# 0         13681.0            None  136.0    Haninge
# 1         76297.0     SKOLVÄGEN 2  188.0  Norrtälje
# 2         76021.0            HARG  188.0  Norrtälje
# 3         76015.0  GRÄDDÖ BYVÄG 6  188.0  Norrtälje
# 4         76015.0  GRÄDDÖ BYVÄG 6  188.0  Norrtälje
# ...           ...             ...    ...        ...
# 15579         NaN             NaN    NaN        NaN
# 15580         NaN             NaN    NaN        NaN
# 15581         NaN             NaN    NaN        NaN
# 15582         NaN             NaN    NaN        NaN
# 15583         NaN             NaN    NaN        NaN
#
#                                                 geometry
# 0                         POINT (680023.000 6543945.000)
# 1                         POINT (694838.000 6644846.000)
# 2                         POINT (721737.000 6636751.000)
# 3                         POINT (726193.000 6631793.000)
# 4                         POINT (726193.000 6631793.000)
# ...                                                  ...
# 15579  POLYGON ((354505.508 6557539.452, 354769.449 6...
# 15580  POLYGON ((369392.176 6548316.729, 369309.202 6...
# 15581  POLYGON ((366577.011 6545743.963, 366902.590 6...
# 15582  MULTIPOLYGON (((401684.370 6729591.121, 401677...
# 15583  POLYGON ((391590.269 6746800.688, 391558.481 6...
#
# [15584 rows x 41 columns]

# %% [markdown]
# #### Symmetric Difference

# %%
sd=gpd.overlay(population,preschools,how='symmetric_difference',keep_geom_type=False)
sd.plot(figsize=(14,3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Difference

# %%
difference= gpd.overlay(population,preschools,how='difference',keep_geom_type=False)
difference.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Dissolve

# %%
union=gpd.overlay(population,preschools,how='union',keep_geom_type=False)
union['common_col']=1

# %%
disolved=union.dissolve(by='common_col')
disolved.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### New York City Child Care Centre and Population statistics

# %%
#Read NY neighbourhood shape file
ny = gpd.read_file("nynta.shp")

# %%
ny.tail()
# Out:
#      BoroCode   BoroName CountyFIPS NTACode                         NTAName  \
# 190         3   Brooklyn        047    BK93                   Starrett City
# 191         3   Brooklyn        047    BK73           North Side-South Side
# 192         3   Brooklyn        047    BK90               East Williamsburg
# 193         1  Manhattan        061    MN21                        Gramercy
# 194         1  Manhattan        061    MN50  Stuyvesant Town-Cooper Village
#
#        Shape_Leng    Shape_Area  \
# 190  17414.782263  1.159895e+07
# 191  28149.966570  2.887016e+07
# 192  49247.014740  3.913241e+07
# 193  12096.891069  7.526916e+06
# 194  12021.748771  5.582242e+06
#
#                                               geometry
# 190  MULTIPOLYGON (((1015251.087 174914.561, 101524...
# 191  POLYGON ((995851.916 203199.332, 995969.192 20...
# 192  POLYGON ((1005302.497 199455.730, 1005307.792 ...
# 193  POLYGON ((990196.892 207745.371, 990187.613 20...
# 194  MULTIPOLYGON (((994681.406 203127.675, 994780....

# %%
#Read NY city child care centers
child_care=pd.read_csv("Child_Care_Centers.csv")

# %%
child_care.head()
# Out:
#               X             Y  OBJECTID          ID  \
# 0 -9.481339e+06  5.028492e+06         1  1222260097
# 1 -9.760009e+06  5.086024e+06         2   120560466
# 2 -1.052294e+07  4.712447e+06         3   116064137
# 3 -1.332006e+07  4.411510e+06         4  1222239999
# 4 -1.356230e+07  4.642993e+06         5  1222244651
#
#                                           NAME                        ADDRESS  \
# 0          MATTHEW'S HOUSE CHILD CARE MINISTRY               2305 GOSHEN ROAD
# 1           PK'S CHRISTIAN LEARNING SITE 2 INC                     9 NORTH ST
# 2      CERNER KIDS REALIZATION LEARNING CENTER         10450 HICKMAN MILLS DR
# 3  CHILD DEVELOPMENT STATE PRESCHOOL - FREEDOM                2955 GETTYSBURG
# 4               EARLY LEARNING CENTER OF DIXON  355 NORTH ALMOND ST., ROOM 21
#
#           CITY STATE    ZIP           ZIP4  ...   LATITUDE   LONGITUDE  \
# 0   FORT WAYNE    IN  46808  NOT AVAILABLE  ...  41.109406  -85.172318
# 1  PARK FOREST    IL  60466  NOT AVAILABLE  ...  41.497650  -87.675652
# 2  KANSAS CITY    MO  64137  NOT AVAILABLE  ...  38.935574  -94.529182
# 3       CLOVIS    CA  93611  NOT AVAILABLE  ...  36.801754 -119.656140
# 4        DIXON    CA  95620  NOT AVAILABLE  ...  38.448597 -121.832180
#
#   NAICS_CODE              NAICS_DESC  \
# 0     624410  CHILD DAY CARE CENTERS
# 1     624410  CHILD DAY CARE CENTERS
# 2     624410  CHILD DAY CARE CENTERS
# 3     624410  CHILD DAY CARE CENTERS
# 4     624410  CHILD DAY CARE CENTERS
#
#                                               SOURCE           SOURCEDATE  \
# 0  https://secure.in.gov/apps/fssa/carefinder/ind...  2019/09/18 00:00:00
# 1  http://nw.inccrra.org/naccrrajsp/servlet/naccr...  2018/09/18 00:00:00
# 2  https://webapp01.dhss.mo.gov/childcaresearch/S...  2018/12/03 00:00:00
# 3  https://secure.dss.ca.gov/CareFacilitySearch/H...  2017/12/16 00:00:00
# 4  https://secure.dss.ca.gov/CareFacilitySearch/H...  2017/12/16 00:00:00
#
#       VAL_METHOD             VAL_DATE        WEBSITE     ST_SUBTYPE
# 0        IMAGERY  2018/12/03 00:00:00  NOT AVAILABLE  NOT AVAILABLE
# 1        IMAGERY  2018/11/16 00:00:00  NOT AVAILABLE  NOT AVAILABLE
# 2        IMAGERY  2016/03/18 00:00:00  NOT AVAILABLE  NOT AVAILABLE
# 3  IMAGERY/OTHER  2019/03/01 00:00:00  NOT AVAILABLE  NOT AVAILABLE
# 4  IMAGERY/OTHER  2019/09/30 00:00:00  NOT AVAILABLE  NOT AVAILABLE
#
# [5 rows x 27 columns]

# %%
#filter for NY city
#child_care_ny=child_care[child_care['CITY']=='NEW YORK CITY']

# %%
child_care_ny=child_care[child_care['STATE']=='NY']

# %%
child_care_ny.shape
# Out:
# (6602, 27)

# %%
child_care_ny.tail()
# Out:
#                    X             Y  OBJECTID          ID  \
# 120978 -8.233264e+06  4.969400e+06    121184  1222245194
# 121001 -8.799825e+06  5.327712e+06    121207  1222279710
# 121002 -8.202666e+06  5.050415e+06    121208  1222252788
# 121058 -8.726800e+06  5.344651e+06    121264  1222248302
# 121059 -8.775795e+06  5.295150e+06    121265  1222259088
#
#                                                     NAME  \
# 120978                        EL PUENTE @ WILLIAMS PLAZA
# 121001                              YMCA BUFFALO NIAGARA
# 121002                        KATONAH VILLAGE KIDS, INC.
# 121058                                         GLOW YMCA
# 121059  LT. COL. MATT URBAN HUMAN SERVICES CENTER OF WNY
#
#                        ADDRESS           CITY STATE    ZIP           ZIP4  \
# 120978     323 ROEBLING STREET       BROOKLYN    NY  11211  NOT AVAILABLE
# 121001    1625 LOCKPORT STREET  NIAGARA FALLS    NY  14305  NOT AVAILABLE
# 121002         31 BEDFORD ROAD        KATONAH    NY  10536  NOT AVAILABLE
# 121058  335 W. OAK ORCHARD ST.         MEDINA    NY  14103  NOT AVAILABLE
# 121059    385 PADEREWSKI DRIVE        BUFFALO    NY  14212  NOT AVAILABLE
#
#         ...   LATITUDE  LONGITUDE NAICS_CODE              NAICS_DESC  \
# 120978  ...  40.708225 -73.960670     624410  CHILD DAY CARE CENTERS
# 121001  ...  43.103321 -79.050179     624410  CHILD DAY CARE CENTERS
# 121002  ...  41.257618 -73.685799     624410  CHILD DAY CARE CENTERS
# 121058  ...  43.214325 -78.394180     624410  CHILD DAY CARE CENTERS
# 121059  ...  42.889385 -78.834312     624410  CHILD DAY CARE CENTERS
#
#                                                    SOURCE  \
# 120978  https://a816-healthpsi.nyc.gov/ChildCare/Child...
# 121001  http://ocfs.ny.gov/main/childcare/ccfs_templat...
# 121002  http://ocfs.ny.gov/main/childcare/ccfs_templat...
# 121058  http://ocfs.ny.gov/main/childcare/ccfs_templat...
# 121059  http://ocfs.ny.gov/main/childcare/ccfs_templat...
#
#                  SOURCEDATE     VAL_METHOD             VAL_DATE  \
# 120978  2018/11/20 00:00:00        IMAGERY  2019/03/20 00:00:00
# 121001  2018/11/20 00:00:00        IMAGERY  2018/06/29 00:00:00
# 121002  2018/11/20 00:00:00  IMAGERY/OTHER  2019/03/20 00:00:00
# 121058  2018/11/20 00:00:00  IMAGERY/OTHER  2019/03/20 00:00:00
# 121059  2018/11/20 00:00:00  IMAGERY/OTHER  2019/03/20 00:00:00
#
#               WEBSITE     ST_SUBTYPE
# 120978  NOT AVAILABLE  NOT AVAILABLE
# 121001  NOT AVAILABLE  NOT AVAILABLE
# 121002  NOT AVAILABLE  NOT AVAILABLE
# 121058  NOT AVAILABLE  NOT AVAILABLE
# 121059  NOT AVAILABLE  NOT AVAILABLE
#
# [5 rows x 27 columns]

# %%
child_care_ny=child_care_ny.drop(['OBJECTID','ID','ZIP4','TELEPHONE','STATUS','POPULATION','COUNTYFIPS','COUNTRY','NAICS_CODE','NAICS_DESC','SOURCE','SOURCEDATE','VAL_METHOD','VAL_DATE','WEBSITE','ST_SUBTYPE','CITY','STATE'],axis=1)

# %%
child_care_ny.head()
# Out:
#                  X             Y  \
# 1042 -8.576113e+06  5.347010e+06
# 1043 -8.605774e+06  5.322120e+06
# 1044 -8.779693e+06  5.319755e+06
# 1045 -8.400522e+06  5.347445e+06
# 1046 -8.220696e+06  4.971327e+06
#
#                                                  NAME  \
# 1042                   WAYNE CAP INC.SODUS HEAD START
# 1043  CREATIVE ENVIRONMENT CHILDREN'S LEARNING CENTER
# 1044                             YMCA BUFFALO NIAGARA
# 1045                   YMCA OF THE GREATER TRI-VALLEY
# 1046                          FOREST HILLS JEWISH CTR
#
#                       ADDRESS    ZIP          TYPE   COUNTY   LATITUDE  \
# 1042      7192 OLD RIDGE ROAD  14551    HEAD START    WAYNE  43.229763
# 1043           28 MAIN STREET  14502  CENTER BASED    WAYNE  43.066639
# 1044         455 MEADOW DRIVE  14120  CENTER BASED  NIAGARA  43.051113
# 1045         1001 RUBY STREET  13440  CENTER BASED   ONEIDA  43.232613
# 1046  106-06 QUEENS BOULEVARD  11375  CENTER BASED   QUEENS  40.721348
#
#       LONGITUDE
# 1042 -77.040535
# 1043 -77.306984
# 1044 -78.869324
# 1045 -75.463181
# 1046 -73.847771

# %%
child_care_ny=child_care_ny.reset_index(drop=True)
child_care_ny.to_csv (r'C:\Users\Anupama\Geomap\child_care_ny.csv', index = False, header=True)

# %%
#drop old dataframe

# %%
#Use the new dataframe from here
child_care_nyc=pd.read_csv("child_care_ny.csv")

# %%
child_care_ny_gdf = gpd.GeoDataFrame(
    child_care_nyc, geometry=gpd.points_from_xy(child_care_nyc.LONGITUDE, child_care_nyc.LATITUDE))

# %%
child_care_ny_gdf.geometry=child_care_ny_gdf.geometry.set_crs("EPSG:4326")

# %%
#Read newyork city borough
nybb= gpd.read_file(gpd.datasets.get_path('nybb'))

# %%
nybb.head(50)
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %% [markdown]
# #### Plot on nybb

# %%
#projected to EPSG:2263
child_care_ny_proj= child_care_ny_gdf.to_crs("EPSG:2263")
child_care_ny_proj.head()
# Out:
#               X             Y  \
# 0 -8.576113e+06  5.347010e+06
# 1 -8.605774e+06  5.322120e+06
# 2 -8.779693e+06  5.319755e+06
# 3 -8.400522e+06  5.347445e+06
# 4 -8.220696e+06  4.971327e+06
#
#                                               NAME                  ADDRESS  \
# 0                   WAYNE CAP INC.SODUS HEAD START      7192 OLD RIDGE ROAD
# 1  CREATIVE ENVIRONMENT CHILDREN'S LEARNING CENTER           28 MAIN STREET
# 2                             YMCA BUFFALO NIAGARA         455 MEADOW DRIVE
# 3                   YMCA OF THE GREATER TRI-VALLEY         1001 RUBY STREET
# 4                          FOREST HILLS JEWISH CTR  106-06 QUEENS BOULEVARD
#
#      ZIP          TYPE   COUNTY   LATITUDE  LONGITUDE  \
# 0  14551    HEAD START    WAYNE  43.229763 -77.040535
# 1  14502  CENTER BASED    WAYNE  43.066639 -77.306984
# 2  14120  CENTER BASED  NIAGARA  43.051113 -78.869324
# 3  13440  CENTER BASED   ONEIDA  43.232613 -75.463181
# 4  11375  CENTER BASED   QUEENS  40.721348 -73.847771
#
#                           geometry
# 0   POINT (173337.915 1130499.327)
# 1   POINT (100062.360 1073611.929)
# 2  POINT (-317613.574 1087449.905)
# 3   POINT (593976.099 1120723.620)
# 4   POINT (1026446.646 202119.726)

# %%
from geopandas.tools import sjoin
child_care_ny_clean = sjoin(child_care_ny_proj,nybb , how="inner", op='intersects')
child_care_ny_clean = child_care_ny_clean.drop(['index_right'], axis=1)
child_care_ny_clean=child_care_ny_clean.reset_index(drop=True)
child_care_ny_clean.head()
# Out:
#               X             Y  \
# 0 -8.220696e+06  4.971327e+06
# 1 -8.209953e+06  4.954333e+06
# 2 -8.212164e+06  4.978432e+06
# 3 -8.212691e+06  4.964484e+06
# 4 -8.230883e+06  4.976798e+06
#
#                                                 NAME  \
# 0                            FOREST HILLS JEWISH CTR
# 1                             WHDC CHRISTIAN ACADEMY
# 2        SPORTS & ARTS IN SCHOOLS FOUNDATION @ PS 41
# 3  THE CHILD CENTER OF NY, INC. @ BASIE BEACON IS 72
# 4           JACOB A. RIIS SETTLEMENT HOUSE @ PS 111Q
#
#                       ADDRESS    ZIP          TYPE  COUNTY   LATITUDE  \
# 0     106-06 QUEENS BOULEVARD  11375  CENTER BASED  QUEENS  40.721348
# 1         1521 CENTRAL AVENUE  11691  CENTER BASED  QUEENS  40.605549
# 2          214-43 35TH AVENUE  11361  CENTER BASED  QUEENS  40.769707
# 3  133-25 GUY R. BREWER BLVD.  11434  CENTER BASED  QUEENS  40.674740
# 4           37-15 13TH STREET  11101  CENTER BASED  QUEENS  40.758587
#
#    LONGITUDE                        geometry  BoroCode BoroName  \
# 0 -73.847771  POINT (1026446.646 202119.726)         4   Queens
# 1 -73.751266  POINT (1053316.788 159992.282)         4   Queens
# 2 -73.771118  POINT (1047648.160 219784.618)         4   Queens
# 3 -73.775864  POINT (1046422.095 185181.925)         4   Queens
# 4 -73.939285  POINT (1001070.310 215656.239)         4   Queens
#
#       Shape_Leng    Shape_Area
# 0  896344.047763  3.045213e+09
# 1  896344.047763  3.045213e+09
# 2  896344.047763  3.045213e+09
# 3  896344.047763  3.045213e+09
# 4  896344.047763  3.045213e+09

# %%
#Plot child care centers with nybb
ax = nybb.plot(figsize=(30,20),color='yellow', edgecolor='black')
child_care_ny_clean.plot(ax=ax, color='red')

plt.show()

# %%
child_care_ny_clean= child_care_ny_clean.to_crs("EPSG:4326")

# %%
community = gpd.read_file("community/geo_export_929fbe61-87e0-40af-a1ec-4f4884bb6b3e.shp")

# %%
#Plot the points in community

ax = community.plot(figsize=(20,10),color='orange', edgecolor='green')
child_care_ny_clean.plot(ax=ax, color='red')

plt.show()

# %%
community['boro_cd'] = community['boro_cd'].astype('int64')

# %%
child_population=pd.read_csv("child_pop.csv")

# %%
child_population.head()
# Out:
#                     location      age_group  year       count  boro_cd
# 0       Battery Park/Tribeca  Under 5 Years  2019  3293.34669      101
# 1          Greenwich Village  Under 5 Years  2019  4861.65331      102
# 2            Lower East Side  Under 5 Years  2019  4967.00000      103
# 3            Chelsea/Clinton  Under 5 Years  2019  3532.84799      104
# 4  Midtown Business District  Under 5 Years  2019  1768.15201      105

# %%
child_population.shape
# Out:
# (59, 5)

# %%
population_community  = community.merge(child_population, on='boro_cd', how='right')

# %%
population_community.head()
# Out:
#    boro_cd    shape_area    shape_leng  \
# 0      101  4.268912e+07  74168.587892
# 1      102  3.768921e+07  34130.595277
# 2      103  4.687978e+07  30695.640963
# 3      104  4.931172e+07  67623.669901
# 4      105  4.379033e+07  35288.188510
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...
# 1  POLYGON ((-73.99684 40.73736, -73.99362 40.736...
# 2  POLYGON ((-73.97177 40.72582, -73.97179 40.725...
# 3  POLYGON ((-73.99394 40.77318, -73.99370 40.773...
# 4  POLYGON ((-73.97301 40.76428, -73.97141 40.763...
#
#                     location      age_group  year       count
# 0       Battery Park/Tribeca  Under 5 Years  2019  3293.34669
# 1          Greenwich Village  Under 5 Years  2019  4861.65331
# 2            Lower East Side  Under 5 Years  2019  4967.00000
# 3            Chelsea/Clinton  Under 5 Years  2019  3532.84799
# 4  Midtown Business District  Under 5 Years  2019  1768.15201

# %%
child_care_ny_clean.head()
# Out:
#               X             Y  \
# 0 -8.220696e+06  4.971327e+06
# 1 -8.209953e+06  4.954333e+06
# 2 -8.212164e+06  4.978432e+06
# 3 -8.212691e+06  4.964484e+06
# 4 -8.230883e+06  4.976798e+06
#
#                                                 NAME  \
# 0                            FOREST HILLS JEWISH CTR
# 1                             WHDC CHRISTIAN ACADEMY
# 2        SPORTS & ARTS IN SCHOOLS FOUNDATION @ PS 41
# 3  THE CHILD CENTER OF NY, INC. @ BASIE BEACON IS 72
# 4           JACOB A. RIIS SETTLEMENT HOUSE @ PS 111Q
#
#                       ADDRESS    ZIP          TYPE  COUNTY   LATITUDE  \
# 0     106-06 QUEENS BOULEVARD  11375  CENTER BASED  QUEENS  40.721348
# 1         1521 CENTRAL AVENUE  11691  CENTER BASED  QUEENS  40.605549
# 2          214-43 35TH AVENUE  11361  CENTER BASED  QUEENS  40.769707
# 3  133-25 GUY R. BREWER BLVD.  11434  CENTER BASED  QUEENS  40.674740
# 4           37-15 13TH STREET  11101  CENTER BASED  QUEENS  40.758587
#
#    LONGITUDE                    geometry  BoroCode BoroName     Shape_Leng  \
# 0 -73.847771  POINT (-73.84777 40.72135)         4   Queens  896344.047763
# 1 -73.751266  POINT (-73.75127 40.60555)         4   Queens  896344.047763
# 2 -73.771118  POINT (-73.77112 40.76971)         4   Queens  896344.047763
# 3 -73.775864  POINT (-73.77586 40.67474)         4   Queens  896344.047763
# 4 -73.939285  POINT (-73.93928 40.75859)         4   Queens  896344.047763
#
#      Shape_Area
# 0  3.045213e+09
# 1  3.045213e+09
# 2  3.045213e+09
# 3  3.045213e+09
# 4  3.045213e+09

# %%
fig, ax = plt.subplots(figsize=(18,16))
population_community.plot(column='count', scheme='Quantiles', k=5, cmap='winter', legend=True, ax=ax)
plt.tight_layout()
plt.title('Choropleth Map - Children Ages between 0 - 5 in NYC', fontsize= 15,  y=0.5)
plt.savefig('choroplethmap.png', bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
fig,ax= plt.subplots(figsize=(18,16))
ax.set_aspect('equal')

population_community.plot(column='count', scheme='Quantiles', k=5, cmap='YlGnBu', legend=True, ax=ax);
child_care_ny_clean.plot(ax=ax, color='red', markersize=1)
#plt.tight_layout()
#ax.set_axis_off()
plt.title('Children Ages 0 - 5 and Preschools')
plt.savefig('choroplethmap_and_preschools.png', bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Spatial Joins

# %%
pop_schools=gpd.sjoin(population_community,child_care_ny_clean,op='contains')

# %%
pop_schools.head()
# Out:
#    boro_cd    shape_area    shape_leng  \
# 0      101  4.268912e+07  74168.587892
# 0      101  4.268912e+07  74168.587892
# 0      101  4.268912e+07  74168.587892
# 0      101  4.268912e+07  74168.587892
# 0      101  4.268912e+07  74168.587892
#
#                                             geometry              location  \
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...  Battery Park/Tribeca
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...  Battery Park/Tribeca
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...  Battery Park/Tribeca
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...  Battery Park/Tribeca
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...  Battery Park/Tribeca
#
#        age_group  year       count  index_right             X  ...  \
# 0  Under 5 Years  2019  3293.34669         2502 -8.237841e+06  ...
# 0  Under 5 Years  2019  3293.34669         2548 -8.239227e+06  ...
# 0  Under 5 Years  2019  3293.34669         2344 -8.238875e+06  ...
# 0  Under 5 Years  2019  3293.34669         2504 -8.238112e+06  ...
# 0  Under 5 Years  2019  3293.34669         2267 -8.238113e+06  ...
#
#                 ADDRESS    ZIP          TYPE    COUNTY   LATITUDE  LONGITUDE  \
# 0        1 POLICE PLAZA  10038  CENTER BASED  NEW YORK  40.712177 -74.001785
# 0       200 WEST STREET  10282  CENTER BASED  NEW YORK  40.714241 -74.014236
# 0  275 GREENWICH STREET  10007  CENTER BASED  NEW YORK  40.715164 -74.011078
# 0      26 FEDERAL PLAZA  10007  CENTER BASED  NEW YORK  40.715431 -74.004219
# 0      26 FEDERAL PLAZA  10007  CENTER BASED  NEW YORK  40.715450 -74.004227
#
#    BoroCode   BoroName     Shape_Leng    Shape_Area
# 0         1  Manhattan  359299.096471  6.364715e+08
# 0         1  Manhattan  359299.096471  6.364715e+08
# 0         1  Manhattan  359299.096471  6.364715e+08
# 0         1  Manhattan  359299.096471  6.364715e+08
# 0         1  Manhattan  359299.096471  6.364715e+08
#
# [5 rows x 22 columns]

# %%
grouped_pop = pop_schools.groupby('boro_cd').size()

# %%
df = grouped_pop.to_frame().reset_index()

# %%
df.head()
# Out:
#    boro_cd    0
# 0      101   32
# 1      102   22
# 2      103  111
# 3      104   33
# 4      105   40

# %%
df.columns = ['boro_cd', 'preschool_count']

# %%
merged_population = population_community.merge(df, on='boro_cd', how='outer')

# %%
merged_population['preschool_count'].fillna(0,inplace=True)

# %%
merged_population['preschool_count'] = merged_population['preschool_count'].astype(int)

# %%
merged_population.sort_values(by=['preschool_count'],ascending=False)
# Out:
#     boro_cd    shape_area     shape_leng  \
# 53      412  2.673332e+08   65928.310532
# 2       103  4.687978e+07   30695.640963
# 10      111  6.614601e+07   59502.908851
# 40      317  9.381023e+07   43326.833881
# 26      303  7.946136e+07   36213.696218
# 6       107  5.315284e+07   39863.651204
# 48      407  3.282884e+08  145453.728681
# 54      413  3.504694e+08  140593.306905
# 7       108  5.517242e+07   53926.902271
# 56      501  3.772536e+08  153873.506331
# 28      305  1.554823e+08   65113.711020
# 32      309  4.532626e+07   29944.420102
# 25      302  7.932940e+07   74179.796950
# 9       110  3.908461e+07   35825.047500
# 24      301  1.317423e+08   68957.445782
# 41      318  2.354569e+08  189415.464988
# 37      314  8.217567e+07   49291.791980
# 11      112  7.796661e+07   56219.719655
# 42      401  1.714932e+08   90662.040794
# 49      408  2.075592e+08   70107.627122
# 14      203  4.480308e+07   33500.896741
# 12      201  6.040112e+07   33416.359016
# 39      316  5.176889e+07   32997.558476
# 20      209  1.142787e+08   62244.108859
# 35      312  9.952558e+07   52245.812071
# 8       109  4.189220e+07   34958.984128
# 31      308  4.559314e+07   38229.468230
# 29      306  8.549757e+07   82130.340466
# 15      204  5.553380e+07   31291.327886
# 17      206  4.266431e+07   35875.711043
# 38      315  1.316430e+08  115288.430606
# 23      212  1.548975e+08   83997.978975
# 57      502  5.927157e+08  143044.989836
# 22      211  1.003138e+08   45740.735124
# 27      304  5.666255e+07   37007.766849
# 16      205  3.831698e+07   29443.048433
# 55      414  1.964929e+08  216788.633712
# 44      403  8.348986e+07   41654.810595
# 58      503  5.990534e+08  193564.186317
# 46      405  2.103957e+08   70005.193191
# 4       105  4.379033e+07   35288.188510
# 52      411  2.608685e+08   97508.948280
# 21      210  1.790882e+08  277895.287263
# 19      208  9.207164e+07   47817.431549
# 34      311  1.031778e+08   51549.556987
# 36      313  8.819569e+07   65821.875435
# 33      310  1.113282e+08   44788.108953
# 45      404  6.573966e+07   37018.373179
# 30      307  1.041307e+08   87416.933054
# 43      402  1.399660e+08   72092.779312
# 3       104  4.931172e+07   67623.669901
# 0       101  4.268912e+07   74168.587892
# 18      207  5.331177e+07   44812.122162
# 50      409  1.073796e+08   50771.345186
# 5       106  3.873266e+07   43387.541113
# 47      406  8.270239e+07   42758.960578
# 13      202  6.185523e+07   49485.218683
# 1       102  3.768921e+07   34130.595277
# 51      410  1.720945e+08  105838.695668
#
#                                              geometry  \
# 53  POLYGON ((-73.80168 40.66632, -73.80167 40.666...
# 2   POLYGON ((-73.97177 40.72582, -73.97179 40.725...
# 10  MULTIPOLYGON (((-73.92134 40.80085, -73.92114 ...
# 40  POLYGON ((-73.90755 40.65119, -73.90849 40.650...
# 26  POLYGON ((-73.91805 40.68721, -73.91800 40.686...
# 6   POLYGON ((-73.95965 40.80116, -73.95848 40.800...
# 48  MULTIPOLYGON (((-73.85255 40.76007, -73.85224 ...
# 54  POLYGON ((-73.74700 40.63689, -73.74701 40.636...
# 7   MULTIPOLYGON (((-73.93557 40.77192, -73.93566 ...
# 56  MULTIPOLYGON (((-74.15946 40.64145, -74.15975 ...
# 28  POLYGON ((-73.86841 40.69473, -73.86868 40.694...
# 32  POLYGON ((-73.92872 40.66450, -73.92905 40.664...
# 25  POLYGON ((-73.96929 40.70709, -73.96839 40.706...
# 9   POLYGON ((-73.93445 40.83598, -73.93456 40.835...
# 24  POLYGON ((-73.92406 40.71411, -73.92404 40.714...
# 41  MULTIPOLYGON (((-73.91513 40.58627, -73.91510 ...
# 37  POLYGON ((-73.95630 40.65505, -73.95616 40.653...
# 11  POLYGON ((-73.93445 40.83598, -73.93464 40.836...
# 42  MULTIPOLYGON (((-73.90647 40.79018, -73.90251 ...
# 49  POLYGON ((-73.81736 40.70455, -73.81740 40.704...
# 14  POLYGON ((-73.88072 40.83752, -73.88074 40.837...
# 12  POLYGON ((-73.91189 40.82214, -73.91182 40.822...
# 39  POLYGON ((-73.90405 40.67922, -73.90349 40.678...
# 20  POLYGON ((-73.83979 40.83562, -73.83967 40.835...
# 35  POLYGON ((-73.97140 40.64826, -73.97121 40.647...
# 8   POLYGON ((-73.94014 40.83037, -73.93963 40.830...
# 31  POLYGON ((-73.95829 40.67983, -73.95596 40.679...
# 29  POLYGON ((-74.00174 40.69241, -74.00170 40.692...
# 15  POLYGON ((-73.90269 40.84458, -73.90271 40.844...
# 17  POLYGON ((-73.87185 40.84376, -73.87192 40.843...
# 38  POLYGON ((-73.91809 40.58657, -73.91813 40.586...
# 23  POLYGON ((-73.79386 40.88364, -73.79417 40.882...
# 57  MULTIPOLYGON (((-74.07347 40.57839, -74.07345 ...
# 22  POLYGON ((-73.82834 40.86089, -73.82843 40.860...
# 27  POLYGON ((-73.89647 40.68234, -73.89653 40.682...
# 16  POLYGON ((-73.89138 40.86170, -73.89142 40.861...
# 55  MULTIPOLYGON (((-73.91193 40.56581, -73.91192 ...
# 44  POLYGON ((-73.86275 40.76676, -73.86272 40.766...
# 58  MULTIPOLYGON (((-74.13320 40.53631, -74.13301 ...
# 46  POLYGON ((-73.88770 40.73429, -73.88711 40.732...
# 4   POLYGON ((-73.97301 40.76428, -73.97141 40.763...
# 52  POLYGON ((-73.71352 40.75984, -73.71426 40.759...
# 21  MULTIPOLYGON (((-73.78833 40.83467, -73.78931 ...
# 19  POLYGON ((-73.89663 40.91142, -73.89663 40.911...
# 34  POLYGON ((-73.97299 40.60881, -73.97259 40.606...
# 36  POLYGON ((-73.98372 40.59582, -73.98305 40.595...
# 33  POLYGON ((-74.03231 40.64404, -74.03201 40.643...
# 45  POLYGON ((-73.84751 40.73901, -73.84801 40.738...
# 30  POLYGON ((-73.98017 40.66115, -73.98021 40.661...
# 43  POLYGON ((-73.89792 40.75424, -73.89797 40.754...
# 3   POLYGON ((-73.99394 40.77318, -73.99370 40.773...
# 0   MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ...
# 18  POLYGON ((-73.87519 40.87158, -73.87619 40.870...
# 50  POLYGON ((-73.81710 40.70403, -73.81697 40.703...
# 5   MULTIPOLYGON (((-73.96128 40.73016, -73.96128 ...
# 47  POLYGON ((-73.82602 40.71541, -73.82606 40.715...
# 13  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...
# 1   POLYGON ((-73.99684 40.73736, -73.99362 40.736...
# 51  MULTIPOLYGON (((-73.85722 40.65028, -73.85902 ...
#
#                      location      age_group  year        count  \
# 53         Jamaica/St. Albans  Under 5 Years  2019  15071.00000
# 2             Lower East Side  Under 5 Years  2019   4967.00000
# 10                East Harlem  Under 5 Years  2019   5789.00000
# 40              East Flatbush  Under 5 Years  2019   7830.00000
# 26         Bedford Stuyvesant  Under 5 Years  2019  10799.00000
# 6             Upper West Side  Under 5 Years  2019   9310.00000
# 48                   Flushing  Under 5 Years  2019  13718.00000
# 54             Queens Village  Under 5 Years  2019   8525.00000
# 7             Upper East Side  Under 5 Years  2019  13426.00000
# 56                 St. George  Under 5 Years  2019   9129.00000
# 28              East New York  Under 5 Years  2019  14618.00000
# 32        Crown Heights South  Under 5 Years  2019   6534.00000
# 25   Fort Greene/Brooklyn Hts  Under 5 Years  2019   9979.00000
# 9              Central Harlem  Under 5 Years  2019   9117.00000
# 24    Williamsburg/Greenpoint  Under 5 Years  2019  11519.00000
# 41                   Canarsie  Under 5 Years  2019  11234.00000
# 37           Flatbush/Midwood  Under 5 Years  2019  13061.00000
# 11         Washington Heights  Under 5 Years  2019   9222.00000
# 42                    Astoria  Under 5 Years  2019   9237.00000
# 49    Fresh Meadows/Briarwood  Under 5 Years  2019  13337.00000
# 14                 Morrisania  Under 5 Years  2019   7413.56552
# 12                 Mott Haven  Under 5 Years  2019   5961.75746
# 39                Brownsville  Under 5 Years  2019  10733.00000
# 20        Unionport/Soundview  Under 5 Years  2019  10738.00000
# 35               Borough Park  Under 5 Years  2019  19136.00000
# 8              Manhattanville  Under 5 Years  2019   5743.00000
# 31        Crown Heights North  Under 5 Years  2019   8014.00000
# 29                 Park Slope  Under 5 Years  2019   8595.00000
# 15       Concourse/Highbridge  Under 5 Years  2019  12191.00000
# 17               East Tremont  Under 5 Years  2019   7739.43448
# 38             Sheepshead Bay  Under 5 Years  2019  10906.00000
# 23             Williamsbridge  Under 5 Years  2019  11343.00000
# 57                South Beach  Under 5 Years  2019   7523.00000
# 22             Pelham Parkway  Under 5 Years  2019   8285.00000
# 27                   Bushwick  Under 5 Years  2019   4761.00000
# 16         University Heights  Under 5 Years  2019  11080.00000
# 55              The Rockaways  Under 5 Years  2019  10644.00000
# 44            Jackson Heights  Under 5 Years  2019   9450.00000
# 58                Tottenville  Under 5 Years  2019   8780.00000
# 46         Ridgewood/Glendale  Under 5 Years  2019  10857.00000
# 4   Midtown Business District  Under 5 Years  2019   1768.15201
# 52                    Bayside  Under 5 Years  2019   4265.00000
# 21                Throgs Neck  Under 5 Years  2019   4437.00000
# 19                  Riverdale  Under 5 Years  2019   6729.00000
# 34                Bensonhurst  Under 5 Years  2019  13299.00000
# 36               Coney Island  Under 5 Years  2019   7051.00000
# 33                  Bay Ridge  Under 5 Years  2019   6566.00000
# 45            Elmhurst/Corona  Under 5 Years  2019  10551.00000
# 30                Sunset Park  Under 5 Years  2019   8152.00000
# 43         Sunnyside/Woodside  Under 5 Years  2019   8603.00000
# 3             Chelsea/Clinton  Under 5 Years  2019   3532.84799
# 0        Battery Park/Tribeca  Under 5 Years  2019   3293.34669
# 18               Bedford Park  Under 5 Years  2019  10725.00000
# 50                  Woodhaven  Under 5 Years  2019   9414.00000
# 5      Murray Hill/Stuyvesant  Under 5 Years  2019   5101.00000
# 47     Rego Park/Forest Hills  Under 5 Years  2019   7293.00000
# 13                Hunts Point  Under 5 Years  2019   3404.24254
# 1           Greenwich Village  Under 5 Years  2019   4861.65331
# 51               Howard Beach  Under 5 Years  2019   5893.00000
#
#     preschool_count
# 53              111
# 2               111
# 10              107
# 40              102
# 26               82
# 6                79
# 48               79
# 54               78
# 7                76
# 56               73
# 28               73
# 32               71
# 25               69
# 9                69
# 24               67
# 41               66
# 37               63
# 11               62
# 42               61
# 49               60
# 14               60
# 12               60
# 39               56
# 20               54
# 35               51
# 8                51
# 31               51
# 29               51
# 15               51
# 17               49
# 38               48
# 23               48
# 57               45
# 22               44
# 27               43
# 16               42
# 55               41
# 44               41
# 58               41
# 46               40
# 4                40
# 52               39
# 21               38
# 19               36
# 34               35
# 36               35
# 33               35
# 45               34
# 30               34
# 43               33
# 3                33
# 0                32
# 18               30
# 50               29
# 5                28
# 47               27
# 13               25
# 1                22
# 51               20

# %%
fig, ax = plt.subplots(1,2, figsize=(18,18))
merged_population.plot(column='preschool_count', scheme='Quantiles',k=5, cmap='YlGnBu', legend=True, ax=ax[0]);
merged_population.plot(column='count', scheme='Quantiles', k=5, cmap='YlGnBu', legend=True, ax=ax[1]);
plt.tight_layout()
ax[0].set_title("Preschool Count")
ax[1].set_title("Age")
plt.savefig('comparison.png', bbox_inches="tight")
plt.show()

# %%
# Subset two cities
jamaica = population_community[population_community['location'] == 'Upper West Side']
lowereastside = population_community[population_community['location'] == 'Lower East Side']

# %%
jamaica_pre = gpd.sjoin(merged_population,jamaica, op='within' )
lowereastside_pre = gpd.sjoin(merged_population,lowereastside, op='within' )

# %%
import libpysal
from libpysal.weights import Queen, Rook, KNN

# %%
ys = jamaica_pre['preschool_count'].values

# Get Weights (Queen)
wqs = Queen.from_dataframe(jamaica_pre)
wqs.transform = 'r'

# Sptial lag
ylags = libpysal.weights.lag_spatial(wqs, ys)
jamaica_pre['ylag'] = ylags
# Out:
# ('WARNING: ', 0, ' is an island (no neighbors)')

# %%
yg = lowereastside_pre['preschool_count'].values

# Get Weights (Queen)
wqg = Queen.from_dataframe(lowereastside_pre)
wqg.transform = 'r'

# Sptial lag
ylags = libpysal.weights.lag_spatial(wqg, yg)
lowereastside_pre['ylag'] = ylags
# Out:
# ('WARNING: ', 0, ' is an island (no neighbors)')

# %%
lowereastside_pre
# Out:
#    boro_cd_left  shape_area_left  shape_leng_left  \
# 2           103     4.687978e+07     30695.640963
#
#                                             geometry    location_left  \
# 2  POLYGON ((-73.97177 40.72582, -73.97179 40.725...  Lower East Side
#
#   age_group_left  year_left  count_left  preschool_count  index_right  \
# 2  Under 5 Years       2019      4967.0              111            2
#
#    boro_cd_right  shape_area_right  shape_leng_right   location_right  \
# 2            103      4.687978e+07      30695.640963  Lower East Side
#
#   age_group_right  year_right  count_right  ylag
# 2   Under 5 Years        2019       4967.0   0.0

# %%
from esda.moran import Moran_Local

# %%
#moran_loc_s = Moran_Local(ys, wqs)
#moran_loc_g = Moran_Local(yg, wqg)

# %%
fig, ax = plt.subplots(1, 2, figsize=(14,12))
moran_scatterplot(moran_loc_s, p=0.05, ax= ax[0])
moran_scatterplot(moran_loc_g, p=0.05, ax= ax[1])
ax[0].set_title("Stockholm Moran Local Scatterplot")
ax[1].set_title("Gothenburg Moran Local Scatterplot")
plt.savefig('ml_scatter.png')
plt.show()

# %%
wq=Queen.from_shapefile(libpysal.examples.get_path("columbus.shp"))

# %%
wq

# %%
"%.3f"%wq.pct_nonzero
# Out:
# '9.829'

# %% [markdown]
# ##### Geoparsing with Python and Natural Language Processing

# %%
tweets=pd.read_csv("tweets.csv")
tweets.head()
# Out:
#                                               Tweets                Location  \
# 0  RT @DeBruyneKev: We, the Players, stand togeth...  Rio de Janeiro, Brasil
# 1  RT @elijahdaniel: RIP Derrick Scott. They’re o...             Houston, TX
# 2  RT @JWB28: This is why the protest won't end a...               not given
# 3  RT @PeopleMvmt: URGENT: Oakland, CA protestors...                     DMV
# 4  For #BlackLivesMatter action @dogonvillage @ch...               not given
#
#    Sentiment
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3  -0.155556
# 4   0.100000

# %%
#import mordecai

# %%
# !pip uninstall mordecai
# Out:
# ^C
